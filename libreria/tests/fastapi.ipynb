# %%
import fastapi
import fastapi.responses
import threading
import uvicorn
import nest_asyncio

nest_asyncio.apply()

# %%
app = fastapi.FastAPI()
@app.get("/")
async def root():
    return fastapi.responses.HTMLResponse(
        """
        <html>
            <head>
                <title>FastAPI Example</title>
            </head>
            <body>
                <h1>Welcome to FastAPI!</h1>
                <p>This is a simple example of a FastAPI application.</p>
            </body>
        </html>
        """
    )
    
@app.websocket("/ws")
async def websocket_endpoint(websocket: fastapi.WebSocket):
    await websocket.accept()
    try:
        while True:
            data = await websocket.receive_text()
            await websocket.send_text(f"Message text was: {data}")
    except fastapi.WebSocketDisconnect:
        print("WebSocket disconnected")
        
uvicorn.run(app, host="127.0.0.1", port=8000, log_level="debug")
# Out:
# INFO:     Started server process [30359]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:39514 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:39514 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:46430 - "GET /ws HTTP/1.1" 404 Not Found
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET / HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: IOoHpIAHGET8b/vlqkHbAA==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 60016) - "WebSocket /" 403
# DEBUG:    > HTTP/1.1 403 Forbidden
# DEBUG:    > Date: Thu, 05 Jun 2025 21:36:44 GMT
# DEBUG:    > Content-Length: 0
# DEBUG:    > Content-Type: text/plain
# DEBUG:    > Connection: close
# DEBUG:    > [body] (0 bytes)
# INFO:     connection rejected (403 Forbidden)
# DEBUG:    x closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET / HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: aWjSER4rh6IwRBQc67RnmA==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 36156) - "WebSocket /" 403
# DEBUG:    > HTTP/1.1 403 Forbidden
# DEBUG:    > Date: Thu, 05 Jun 2025 21:37:02 GMT
# DEBUG:    > Content-Length: 0
# DEBUG:    > Content-Type: text/plain
# DEBUG:    > Connection: close
# DEBUG:    > [body] (0 bytes)
# INFO:     connection rejected (403 Forbidden)
# DEBUG:    x closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET / HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: hBBCBiAC8Uz7JLgagNkUaA==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 60832) - "WebSocket /" 403
# DEBUG:    > HTTP/1.1 403 Forbidden
# DEBUG:    > Date: Thu, 05 Jun 2025 21:37:09 GMT
# DEBUG:    > Content-Length: 0
# DEBUG:    > Content-Type: text/plain
# DEBUG:    > Connection: close
# DEBUG:    > [body] (0 bytes)
# INFO:     connection rejected (403 Forbidden)
# DEBUG:    x closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET / HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: LK+g/Y1An4NuzeR0BNHsjg==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 60836) - "WebSocket /" 403
# DEBUG:    > HTTP/1.1 403 Forbidden
# DEBUG:    > Date: Thu, 05 Jun 2025 21:37:12 GMT
# DEBUG:    > Content-Length: 0
# DEBUG:    > Content-Type: text/plain
# DEBUG:    > Connection: close
# DEBUG:    > [body] (0 bytes)
# INFO:     connection rejected (403 Forbidden)
# DEBUG:    x closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET / HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: hPuccsebVXjojyBJXnPW1Q==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 60844) - "WebSocket /" 403
# DEBUG:    > HTTP/1.1 403 Forbidden
# DEBUG:    > Date: Thu, 05 Jun 2025 21:37:13 GMT
# DEBUG:    > Content-Length: 0
# DEBUG:    > Content-Type: text/plain
# DEBUG:    > Connection: close
# DEBUG:    > [body] (0 bytes)
# INFO:     connection rejected (403 Forbidden)
# DEBUG:    x closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET / HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: vSUrf2fYiyEf4PU4Ked5VQ==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 60850) - "WebSocket /" 403
# DEBUG:    > HTTP/1.1 403 Forbidden
# DEBUG:    > Date: Thu, 05 Jun 2025 21:37:13 GMT
# DEBUG:    > Content-Length: 0
# DEBUG:    > Content-Type: text/plain
# DEBUG:    > Connection: close
# DEBUG:    > [body] (0 bytes)
# INFO:     connection rejected (403 Forbidden)
# DEBUG:    x closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET /ws HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: e7HyXAwt/+j60n0Bm1Rzpg==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 60442) - "WebSocket /ws" [accepted]
# DEBUG:    > HTTP/1.1 101 Switching Protocols
# DEBUG:    > Upgrade: websocket
# DEBUG:    > Connection: Upgrade
# DEBUG:    > Sec-WebSocket-Accept: jk68WQ4BAdDT896AkMKFdscYR8I=
# DEBUG:    > Sec-WebSocket-Extensions: permessage-deflate
# DEBUG:    > date: Thu, 05 Jun 2025 21:37:57 GMT
# DEBUG:    > server: uvicorn
# INFO:     connection open
# DEBUG:    = connection is OPEN
# DEBUG:    < CLOSE 1001 (going away) [2 bytes]
# DEBUG:    = connection is CLOSING
# DEBUG:    > CLOSE 1001 (going away) [2 bytes]
# DEBUG:    x half-closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET /ws HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: sIAOl4vip8t2ky+jR0jz/w==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 48538) - "WebSocket /ws" [accepted]
# DEBUG:    > HTTP/1.1 101 Switching Protocols
# DEBUG:    > Upgrade: websocket
# DEBUG:    > Connection: Upgrade
# DEBUG:    > Sec-WebSocket-Accept: KWBKpgeM/29e2PrFKprn8Y1zh4Y=
# DEBUG:    > Sec-WebSocket-Extensions: permessage-deflate
# DEBUG:    > date: Thu, 05 Jun 2025 21:38:12 GMT
# DEBUG:    > server: uvicorn
# INFO:     connection open
# DEBUG:    = connection is OPEN
# WebSocket disconnected
# DEBUG:    < CLOSE 1001 (going away) [2 bytes]
# DEBUG:    = connection is CLOSING
# DEBUG:    > CLOSE 1001 (going away) [2 bytes]
# DEBUG:    x half-closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET /ws HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: k0MR8xQIrANkNj5jHoI01A==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 48540) - "WebSocket /ws" [accepted]
# DEBUG:    > HTTP/1.1 101 Switching Protocols
# DEBUG:    > Upgrade: websocket
# DEBUG:    > Connection: Upgrade
# DEBUG:    > Sec-WebSocket-Accept: fWw49YMPdITQgXUJGX+t03Gh0iI=
# DEBUG:    > Sec-WebSocket-Extensions: permessage-deflate
# DEBUG:    > date: Thu, 05 Jun 2025 21:38:12 GMT
# DEBUG:    > server: uvicorn
# INFO:     connection open
# DEBUG:    = connection is OPEN
# WebSocket disconnected
# DEBUG:    < CLOSE 1001 (going away) [2 bytes]
# DEBUG:    = connection is CLOSING
# DEBUG:    > CLOSE 1001 (going away) [2 bytes]
# DEBUG:    x half-closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# WebSocket disconnected
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET /ws HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: EKca+X1aKwpn/YwujPpV2A==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 60656) - "WebSocket /ws" [accepted]
# DEBUG:    > HTTP/1.1 101 Switching Protocols
# DEBUG:    > Upgrade: websocket
# DEBUG:    > Connection: Upgrade
# DEBUG:    > Sec-WebSocket-Accept: 9aFd68sRSw9YKVEhpYsTyO9Y6tc=
# DEBUG:    > Sec-WebSocket-Extensions: permessage-deflate
# DEBUG:    > date: Thu, 05 Jun 2025 21:38:19 GMT
# DEBUG:    > server: uvicorn
# INFO:     connection open
# DEBUG:    = connection is OPEN
# DEBUG:    < CLOSE 1001 (going away) [2 bytes]
# DEBUG:    = connection is CLOSING
# DEBUG:    > CLOSE 1001 (going away) [2 bytes]
# DEBUG:    x half-closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET /ws HTTP/1.1
# DEBUG:    < host: localhost:8000
# WebSocket disconnected
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: 3f2N+F5hKS2wLF60PpsHfw==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 60664) - "WebSocket /ws" [accepted]
# DEBUG:    > HTTP/1.1 101 Switching Protocols
# DEBUG:    > Upgrade: websocket
# DEBUG:    > Connection: Upgrade
# DEBUG:    > Sec-WebSocket-Accept: aZhRWD2mI52iQ87EY0AE8080wR4=
# DEBUG:    > Sec-WebSocket-Extensions: permessage-deflate
# DEBUG:    > date: Thu, 05 Jun 2025 21:38:23 GMT
# DEBUG:    > server: uvicorn
# INFO:     connection open
# DEBUG:    = connection is OPEN
# DEBUG:    < CLOSE 1001 (going away) [2 bytes]
# DEBUG:    = connection is CLOSING
# DEBUG:    > CLOSE 1001 (going away) [2 bytes]
# DEBUG:    x half-closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET /ws HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: pXPpqg0JDUp47socOGdSdg==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 57528) - "WebSocket /ws" [accepted]
# DEBUG:    > HTTP/1.1 101 Switching Protocols
# WebSocket disconnected
# DEBUG:    > Upgrade: websocket
# DEBUG:    > Connection: Upgrade
# DEBUG:    > Sec-WebSocket-Accept: 7NsJFvgpiE0CLEyQgws46xeZ0xk=
# DEBUG:    > Sec-WebSocket-Extensions: permessage-deflate
# DEBUG:    > date: Thu, 05 Jun 2025 21:38:28 GMT
# DEBUG:    > server: uvicorn
# INFO:     connection open
# DEBUG:    = connection is OPEN
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING a2 e0 00 7b [binary, 4 bytes]
# DEBUG:    < PONG a2 e0 00 7b [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    < CLOSE 1001 (going away) [2 bytes]
# DEBUG:    = connection is CLOSING
# DEBUG:    > CLOSE 1001 (going away) [2 bytes]
# DEBUG:    x half-closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# WebSocket disconnected
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET /ws HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: PGVoEuDFUAAIrNMdUBM9ZQ==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 47600) - "WebSocket /ws" [accepted]
# DEBUG:    > HTTP/1.1 101 Switching Protocols
# DEBUG:    > Upgrade: websocket
# DEBUG:    > Connection: Upgrade
# DEBUG:    > Sec-WebSocket-Accept: GJIDOH6v6xJf5e6+aCYXZtgvDqs=
# DEBUG:    > Sec-WebSocket-Extensions: permessage-deflate
# DEBUG:    > date: Thu, 05 Jun 2025 21:39:01 GMT
# DEBUG:    > server: uvicorn
# INFO:     connection open
# DEBUG:    = connection is OPEN
# DEBUG:    < CLOSE 1001 (going away) [2 bytes]
# DEBUG:    = connection is CLOSING
# DEBUG:    > CLOSE 1001 (going away) [2 bytes]
# DEBUG:    x half-closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# WebSocket disconnected
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET /ws HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: mzAfCHoCzMYu2/EfSiwa+w==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 47612) - "WebSocket /ws" [accepted]
# DEBUG:    > HTTP/1.1 101 Switching Protocols
# DEBUG:    > Upgrade: websocket
# DEBUG:    > Connection: Upgrade
# DEBUG:    > Sec-WebSocket-Accept: VkfrAU7xDARr9Rf7yAOI1UeWH+g=
# DEBUG:    > Sec-WebSocket-Extensions: permessage-deflate
# DEBUG:    > date: Thu, 05 Jun 2025 21:39:05 GMT
# DEBUG:    > server: uvicorn
# INFO:     connection open
# DEBUG:    = connection is OPEN
# DEBUG:    < CLOSE 1001 (going away) [2 bytes]
# DEBUG:    = connection is CLOSING
# DEBUG:    > CLOSE 1001 (going away) [2 bytes]
# DEBUG:    x half-closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# WebSocket disconnected
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET /ws HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: aN+6KKt35XTz6NvvgtUpLg==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 47556) - "WebSocket /ws" [accepted]
# DEBUG:    > HTTP/1.1 101 Switching Protocols
# DEBUG:    > Upgrade: websocket
# DEBUG:    > Connection: Upgrade
# DEBUG:    > Sec-WebSocket-Accept: wVrBuEbWmFThLF5OXrkQ7Usye4M=
# DEBUG:    > Sec-WebSocket-Extensions: permessage-deflate
# DEBUG:    > date: Thu, 05 Jun 2025 21:39:14 GMT
# DEBUG:    > server: uvicorn
# INFO:     connection open
# DEBUG:    = connection is OPEN
# DEBUG:    < CLOSE 1001 (going away) [2 bytes]
# DEBUG:    = connection is CLOSING
# DEBUG:    > CLOSE 1001 (going away) [2 bytes]
# DEBUG:    x half-closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# WebSocket disconnected
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET /ws HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: TzSniYv9BUjjnM2IF3Otew==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 49934) - "WebSocket /ws" [accepted]
# DEBUG:    > HTTP/1.1 101 Switching Protocols
# DEBUG:    > Upgrade: websocket
# DEBUG:    > Connection: Upgrade
# DEBUG:    > Sec-WebSocket-Accept: 7Qg1t72fNyqL815PYekI/fGc2kc=
# DEBUG:    > Sec-WebSocket-Extensions: permessage-deflate
# DEBUG:    > date: Thu, 05 Jun 2025 21:39:27 GMT
# DEBUG:    > server: uvicorn
# INFO:     connection open
# DEBUG:    = connection is OPEN
# DEBUG:    < CLOSE 1001 (going away) [2 bytes]
# DEBUG:    = connection is CLOSING
# DEBUG:    > CLOSE 1001 (going away) [2 bytes]
# DEBUG:    x half-closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET /ws HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: wQHRdmEDNFRlCP9GKqTZQA==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 49178) - "WebSocket /ws" [accepted]
# DEBUG:    > HTTP/1.1 101 Switching Protocols
# DEBUG:    > Upgrade: websocket
# DEBUG:    > Connection: Upgrade
# DEBUG:    > Sec-WebSocket-Accept: SQSeXaQQnblv2DJ28Cupy0pS0O0=
# DEBUG:    > Sec-WebSocket-Extensions: permessage-deflate
# DEBUG:    > date: Thu, 05 Jun 2025 21:39:39 GMT
# DEBUG:    > server: uvicorn
# INFO:     connection open
# DEBUG:    = connection is OPEN
# WebSocket disconnected
# DEBUG:    < CLOSE 1001 (going away) [2 bytes]
# DEBUG:    = connection is CLOSING
# DEBUG:    > CLOSE 1001 (going away) [2 bytes]
# DEBUG:    x half-closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET /ws HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: gjnTvmzkdkmylbaFcroLXw==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 

# DEBUG:    > Sec-WebSocket-Extensions: permessage-deflate
# DEBUG:    > date: Thu, 05 Jun 2025 22:35:29 GMT
# DEBUG:    > server: uvicorn
# INFO:     connection open
# DEBUG:    = connection is OPEN
# WebSocket disconnected
# DEBUG:    < CLOSE 1001 (going away) [2 bytes]
# DEBUG:    = connection is CLOSING
# DEBUG:    > CLOSE 1001 (going away) [2 bytes]
# DEBUG:    x half-closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET /ws HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: qI3UWgNqpcdC7W2Ae/Z3Tw==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 44344) - "WebSocket /ws" [accepted]
# DEBUG:    > HTTP/1.1 101 Switching Protocols
# DEBUG:    > Upgrade: websocket
# DEBUG:    > Connection: Upgrade
# DEBUG:    > Sec-WebSocket-Accept: hxHJw//a79fZWsesGuoJ+hV5PDs=
# DEBUG:    > Sec-WebSocket-Extensions: permessage-deflate
# DEBUG:    > date: Thu, 05 Jun 2025 22:35:32 GMT
# DEBUG:    > server: uvicorn
# INFO:     connection open
# DEBUG:    = connection is OPEN
# WebSocket disconnected
# DEBUG:    < CLOSE 1001 (going away) [2 bytes]
# DEBUG:    = connection is CLOSING
# DEBUG:    > CLOSE 1001 (going away) [2 bytes]
# DEBUG:    x half-closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET /ws HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: jZa3o6GN7yqPypAlyQZkcw==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 54322) - "WebSocket /ws" [accepted]
# DEBUG:    > HTTP/1.1 101 Switching Protocols
# DEBUG:    > Upgrade: websocket
# DEBUG:    > Connection: Upgrade
# DEBUG:    > Sec-WebSocket-Accept: uCe+tpbN2/F5g75U7zZbTA4v/Nk=
# DEBUG:    > Sec-WebSocket-Extensions: permessage-deflate
# DEBUG:    > date: Thu, 05 Jun 2025 22:35:42 GMT
# DEBUG:    > server: uvicorn
# INFO:     connection open
# DEBUG:    = connection is OPEN
# WebSocket disconnected
# DEBUG:    < CLOSE 1001 (going away) [2 bytes]
# DEBUG:    = connection is CLOSING
# DEBUG:    > CLOSE 1001 (going away) [2 bytes]
# DEBUG:    x half-closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET /ws HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: NTTSswd2plqmKsdENq6/yQ==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 42262) - "WebSocket /ws" [accepted]
# DEBUG:    > HTTP/1.1 101 Switching Protocols
# DEBUG:    > Upgrade: websocket
# DEBUG:    > Connection: Upgrade
# DEBUG:    > Sec-WebSocket-Accept: L4+HILHt+wjjzufWu08idhAC8fg=
# DEBUG:    > Sec-WebSocket-Extensions: permessage-deflate
# DEBUG:    > date: Thu, 05 Jun 2025 22:35:54 GMT
# DEBUG:    > server: uvicorn
# INFO:     connection open
# DEBUG:    = connection is OPEN
# WebSocket disconnected
# DEBUG:    < CLOSE 1001 (going away) [2 bytes]
# DEBUG:    = connection is CLOSING
# DEBUG:    > CLOSE 1001 (going away) [2 bytes]
# DEBUG:    x half-closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# WebSocket disconnected
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET /ws HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: /FiVWp4qeoqV8kQcCpidog==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 47372) - "WebSocket /ws" [accepted]
# DEBUG:    > HTTP/1.1 101 Switching Protocols
# DEBUG:    > Upgrade: websocket
# DEBUG:    > Connection: Upgrade
# DEBUG:    > Sec-WebSocket-Accept: QC9A6nbBJaILWs5RWwSfdYj3GUg=
# DEBUG:    > Sec-WebSocket-Extensions: permessage-deflate
# DEBUG:    > date: Thu, 05 Jun 2025 22:35:57 GMT
# DEBUG:    > server: uvicorn
# INFO:     connection open
# DEBUG:    = connection is OPEN
# DEBUG:    < CLOSE 1001 (going away) [2 bytes]
# DEBUG:    = connection is CLOSING
# DEBUG:    > CLOSE 1001 (going away) [2 bytes]
# DEBUG:    x half-closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# DEBUG:    = connection is CONNECTING
# DEBUG:    < GET /ws HTTP/1.1
# DEBUG:    < host: localhost:8000
# DEBUG:    < connection: Upgrade
# DEBUG:    < pragma: no-cache
# DEBUG:    < cache-control: no-cache
# DEBUG:    < user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36
# DEBUG:    < accept-language: en;q=0.9
# DEBUG:    < upgrade: websocket
# DEBUG:    < origin: http://localhost:4321
# DEBUG:    < sec-websocket-version: 13
# DEBUG:    < accept-encoding: gzip, deflate, br, zstd
# DEBUG:    < sec-websocket-key: TA1GUO2gycwsXdCSg9q0BQ==
# DEBUG:    < sec-websocket-extensions: permessage-deflate; client_max_window_bits
# INFO:     ('127.0.0.1', 47684) - "WebSocket /ws" [accepted]
# DEBUG:    > HTTP/1.1 101 Switching Protocols
# DEBUG:    > Upgrade: websocket
# DEBUG:    > Connection: Upgrade
# DEBUG:    > Sec-WebSocket-Accept: uUQqVNviBSkoxZeYv9j/HgwLuC0=
# DEBUG:    > Sec-WebSocket-Extensions: permessage-deflate
# DEBUG:    > date: Thu, 05 Jun 2025 22:36:08 GMT
# DEBUG:    > server: uvicorn
# INFO:     connection open
# DEBUG:    = connection is OPEN
# WebSocket disconnected
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING '[iFE' [text, 4 bytes]
# DEBUG:    < PONG '[iFE' [text, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING d9 54 0a d2 [binary, 4 bytes]
# DEBUG:    < PONG d9 54 0a d2 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 43 8d b1 3e [binary, 4 bytes]
# DEBUG:    < PONG 43 8d b1 3e [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 3d b3 6f f7 [binary, 4 bytes]
# DEBUG:    < PONG 3d b3 6f f7 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING a2 5c 69 24 [binary, 4 bytes]
# DEBUG:    < PONG a2 5c 69 24 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 23 b2 56 63 [binary, 4 bytes]
# DEBUG:    < PONG 23 b2 56 63 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 59 f9 16 9e [binary, 4 bytes]
# DEBUG:    < PONG 59 f9 16 9e [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING fe 72 08 b6 [binary, 4 bytes]
# DEBUG:    < PONG fe 72 08 b6 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 25 9a 7c 98 [binary, 4 bytes]
# DEBUG:    < PONG 25 9a 7c 98 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 7d dc dd f8 [binary, 4 bytes]
# DEBUG:    < PONG 7d dc dd f8 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 40 c4 c8 f6 [binary, 4 bytes]
# DEBUG:    < PONG 40 c4 c8 f6 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 72 25 ce 62 [binary, 4 bytes]
# DEBUG:    < PONG 72 25 ce 62 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 2f d4 b6 e5 [binary, 4 bytes]
# DEBUG:    < PONG 2f d4 b6 e5 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING d7 45 99 cb [binary, 4 bytes]
# DEBUG:    < PONG d7 45 99 cb [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 89 67 df b3 [binary, 4 bytes]
# DEBUG:    < PONG 89 67 df b3 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING dc 91 f9 3c [binary, 4 bytes]
# DEBUG:    < PONG dc 91 f9 3c [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 00 c2 df cb [binary, 4 bytes]
# DEBUG:    < PONG 00 c2 df cb [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 78 a4 18 f7 [binary, 4 bytes]
# DEBUG:    < PONG 78 a4 18 f7 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING bf ee 68 2d [binary, 4 bytes]
# DEBUG:    < PONG bf ee 68 2d [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING e3 37 1e 33 [binary, 4 bytes]
# DEBUG:    < PONG e3 37 1e 33 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 05 80 18 3a [binary, 4 bytes]
# DEBUG:    < PONG 05 80 18 3a [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 44 ac 7b 68 [binary, 4 bytes]
# DEBUG:    < PONG 44 ac 7b 68 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING c4 cd 31 6e [binary, 4 bytes]
# DEBUG:    < PONG c4 cd 31 6e [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING ']]ŵ' [text, 4 bytes]
# DEBUG:    < PONG ']]ŵ' [text, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING bf 84 49 4f [binary, 4 bytes]
# DEBUG:    < PONG bf 84 49 4f [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING f9 ef cd 19 [binary, 4 bytes]
# DEBUG:    < PONG f9 ef cd 19 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING c5 08 6f 89 [binary, 4 bytes]
# DEBUG:    < PONG c5 08 6f 89 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 19 f6 c0 29 [binary, 4 bytes]
# DEBUG:    < PONG 19 f6 c0 29 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 61 94 80 4d [binary, 4 bytes]
# DEBUG:    < PONG 61 94 80 4d [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING a8 e6 ed 29 [binary, 4 bytes]
# DEBUG:    < PONG a8 e6 ed 29 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 6e 9e 65 77 [binary, 4 bytes]
# DEBUG:    < PONG 6e 9e 65 77 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 84 b4 08 d4 [binary, 4 bytes]
# DEBUG:    < PONG 84 b4 08 d4 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING db 09 47 17 [binary, 4 bytes]
# DEBUG:    < PONG db 09 47 17 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 9c 72 6b 03 [binary, 4 bytes]
# DEBUG:    < PONG 9c 72 6b 03 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 18 ba 65 b3 [binary, 4 bytes]
# DEBUG:    < PONG 18 ba 65 b3 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 8f b5 b3 66 [binary, 4 bytes]
# DEBUG:    < PONG 8f b5 b3 66 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 1c 26 a1 fb [binary, 4 bytes]
# DEBUG:    < PONG 1c 26 a1 fb [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 'G\x05mo' [text, 4 bytes]
# DEBUG:    < PONG 'G\x05mo' [text, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING '0\\L\x00' [text, 4 bytes]
# DEBUG:    < PONG '0\\L\x00' [text, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING cb b2 5e e1 [binary, 4 bytes]
# DEBUG:    < PONG cb b2 5e e1 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 65 96 79 9c [binary, 4 bytes]
# DEBUG:    < PONG 65 96 79 9c [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 33 5f aa 49 [binary, 4 bytes]
# DEBUG:    < PONG 33 5f aa 49 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 75 db fe 32 [binary, 4 bytes]
# DEBUG:    < PONG 75 db fe 32 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING a7 04 fc 0b [binary, 4 bytes]
# DEBUG:    < PONG a7 04 fc 0b [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 17 f8 11 37 [binary, 4 bytes]
# DEBUG:    < PONG 17 f8 11 37 [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    % sending keepalive ping
# DEBUG:    > PING 7a d9 e4 6e [binary, 4 bytes]
# DEBUG:    < PONG 7a d9 e4 6e [binary, 4 bytes]
# DEBUG:    % received keepalive pong
# DEBUG:    < CLOSE 1001 (going away) [2 bytes]
# DEBUG:    = connection is CLOSING
# DEBUG:    > CLOSE 1001 (going away) [2 bytes]
# DEBUG:    x half-closing TCP connection
# DEBUG:    = connection is CLOSED
# INFO:     connection closed
# WebSocket disconnected
